# %%
import sys
print(sys.version)
# Out:
# 3.13.9 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 19:09:58) [MSC v.1929 64 bit (AMD64)]

# %%
import numpy as np
print(np.__version__)
# Out:
# 2.3.5

# %%
# !pip install torch torchvision torchaudio
# !pip install opencv-python pillow tqdm scikit-image
# Out:
# Requirement already satisfied: torch in c:\users\user\anaconda3\lib\site-packages (2.10.0)
# Requirement already satisfied: torchvision in c:\users\user\anaconda3\lib\site-packages (0.25.0)
# Requirement already satisfied: torchaudio in c:\users\user\anaconda3\lib\site-packages (2.10.0)
# Requirement already satisfied: filelock in c:\users\user\anaconda3\lib\site-packages (from torch) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\user\anaconda3\lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\user\anaconda3\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\user\anaconda3\lib\site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in c:\users\user\anaconda3\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\user\anaconda3\lib\site-packages (from torch) (2025.10.0)
# Requirement already satisfied: setuptools in c:\users\user\anaconda3\lib\site-packages (from torch) (80.9.0)
# Requirement already satisfied: numpy in c:\users\user\anaconda3\lib\site-packages (from torchvision) (2.3.5)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\user\anaconda3\lib\site-packages (from torchvision) (12.0.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\user\anaconda3\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\anaconda3\lib\site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: opencv-python in c:\users\user\anaconda3\lib\site-packages (4.13.0.92)
# Requirement already satisfied: pillow in c:\users\user\anaconda3\lib\site-packages (12.0.0)
# Requirement already satisfied: tqdm in c:\users\user\anaconda3\lib\site-packages (4.67.1)
# Requirement already satisfied: scikit-image in c:\users\user\anaconda3\lib\site-packages (0.25.2)
# Requirement already satisfied: numpy>=2 in c:\users\user\anaconda3\lib\site-packages (from opencv-python) (2.3.5)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: scipy>=1.11.4 in c:\users\user\anaconda3\lib\site-packages (from scikit-image) (1.16.3)
# Requirement already satisfied: networkx>=3.0 in c:\users\user\anaconda3\lib\site-packages (from scikit-image) (3.5)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in c:\users\user\anaconda3\lib\site-packages (from scikit-image) (2.37.2)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\user\anaconda3\lib\site-packages (from scikit-image) (2025.10.4)
# Requirement already satisfied: packaging>=21 in c:\users\user\anaconda3\lib\site-packages (from scikit-image) (25.0)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\user\anaconda3\lib\site-packages (from scikit-image) (0.4)

# %%
import torch
import cv2
import PIL
import tqdm
import skimage

print("All libraries installed successfully!")
print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
# Out:
# All libraries installed successfully!
# PyTorch version: 2.10.0+cpu
# CUDA available: False

# %%
print("Razib")
# Out:
# Razib
